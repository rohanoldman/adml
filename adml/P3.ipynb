# %%
#Practical 3: Deep learning for recognizing classes for datasets like CIFAR-10 images

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
from PIL import Image

# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Preprocess the data by scaling pixel values to the range [0, 1]
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Convert the labels to one-hot encoded vectors
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Define the model architecture
model = keras.Sequential(
    [
        keras.Input(shape=(32, 32, 3)),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(10, activation="softmax"),
    ]
)

# Compile the model with categorical cross-entropy loss and the Adam optimizer
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model on the CIFAR-10 dataset
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test))

# Save the model to a file
model.save("cifar10_model.h5")

# Load the saved model
model = keras.models.load_model("cifar10_model.h5")

# Load and preprocess the test image
img = Image.open("C:/Users/Aniket Singh/Dropbox/PC/Documents/Practical Requirements/two.png")
img = img.resize((32, 32))
img_array = np.array(img)
img_array = img_array.astype("float32") / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Make predictions on the test image
predictions = model.predict(img_array)

# Get the predicted class label
class_label = np.argmax(predictions)

# Print the predicted class label
print("Predicted class label:", class_label)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 202s 248ms/step - loss: 1.6432 - accuracy: 0.4069 - val_loss: 1.3667 - val_accuracy: 0.5138
# Epoch 2/10
# 782/782 [==============================] - 280s 359ms/step - loss: 1.3450 - accuracy: 0.5250 - val_loss: 1.2184 - val_accuracy: 0.5766
# Epoch 3/10
# 782/782 [==============================] - 255s 327ms/step - loss: 1.2372 - accuracy: 0.5663 - val_loss: 1.1331 - val_accuracy: 0.6092
# Epoch 4/10
# 782/782 [==============================] - 118s 151ms/step - loss: 1.1638 - accuracy: 0.5945 - val_loss: 1.0650 - val_accuracy: 0.6336
# Epoch 5/10
# 782/782 [==============================] - 110s 141ms/step - loss: 1.1037 - accuracy: 0.6159 - val_loss: 1.0241 - val_accuracy: 0.6464
# Epoch 6/10
# 782/782 [==============================] - 108s 138ms/step - loss: 1.0655 - accuracy: 0.6292 - val_loss: 0.9964 - val_accuracy: 0.6606
# Epoch 7/10
# 782/782 [==============================] - 105s 134ms/step - loss: 1.0261 - accuracy: 0.6429 - val_loss: 0.9495 - val_accuracy: 0.6748
# Epoch 8/10
# 782/782 [==============================] - 98s 125ms/step - loss: 1.0082 - accuracy: 0.6509 - val_loss: 0.9609 - val_accuracy: 0.6711
# Epoch 9/10
# 782/782 [==============================] - 100s 128ms/step - loss: 0.9847 - accuracy: 0.6579 - val_loss: 0.9344 - val_accuracy: 0.6806
# Epoch 10/10
# 782/782 [==============================] - 99s 126ms/step - loss: 0.9601 - accuracy: 0.6671 - val_loss: 0.9050 - val_accuracy: 0.6899
# Predicted class label: 1

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from PIL import Image

# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# Normalize the pixel values to be between 0 and 1
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Convert the labels to one-hot encoded vectors
y_train = keras.utils.to_categorical(y_train, num_classes=10)
y_test = keras.utils.to_categorical(y_test, num_classes=10)

# Define the model architecture
model = keras.models.Sequential([
    keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.MaxPooling2D((2, 2)),
    keras.layers.Conv2D(64, (3, 3), activation='relu'),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))

# Save the trained model to a file
model.save("cifar10_model.h5")

# Load the saved model
model = keras.models.load_model("cifar10_model.h5")

# Load and preprocess the test image
img = Image.open("C:/Users/Aniket Singh/Dropbox/PC/Documents/Practical Requirements/two.png")
img = img.resize((32, 32))
img_array = np.array(img)
img_array = img_array.astype("float32") / 255.0
img_array = np.expand_dims(img_array, axis=0)

# Make predictions on the test image
predictions = model.predict(img_array)

# Get the predicted class label
class_label = np.argmax(predictions)

# Print the predicted class label
print("Predicted class label:", class_label)
# Out:
# Epoch 1/10
# 782/782 [==============================] - 120s 149ms/step - loss: 1.5631 - accuracy: 0.4291 - val_loss: 1.3244 - val_accuracy: 0.5297
# Epoch 2/10
# 782/782 [==============================] - 98s 126ms/step - loss: 1.2071 - accuracy: 0.5704 - val_loss: 1.1684 - val_accuracy: 0.5929
# Epoch 3/10
# 782/782 [==============================] - 98s 125ms/step - loss: 1.0563 - accuracy: 0.6266 - val_loss: 1.0697 - val_accuracy: 0.6260
# Epoch 4/10
# 782/782 [==============================] - 96s 123ms/step - loss: 0.9555 - accuracy: 0.6639 - val_loss: 0.9578 - val_accuracy: 0.6661
# Epoch 5/10
# 782/782 [==============================] - 74s 95ms/step - loss: 0.8780 - accuracy: 0.6903 - val_loss: 0.9411 - val_accuracy: 0.6719
# Epoch 6/10
# 782/782 [==============================] - 44s 57ms/step - loss: 0.8257 - accuracy: 0.7110 - val_loss: 0.9227 - val_accuracy: 0.6838
# Epoch 7/10
# 782/782 [==============================] - 43s 55ms/step - loss: 0.7704 - accuracy: 0.7289 - val_loss: 0.8442 - val_accuracy: 0.7054
# Epoch 8/10
# 782/782 [==============================] - 46s 58ms/step - loss: 0.7349 - accuracy: 0.7414 - val_loss: 0.8435 - val_accuracy: 0.7121
# Epoch 9/10
# 782/782 [==============================] - 44s 56ms/step - loss: 0.6972 - accuracy: 0.7543 - val_loss: 0.8974 - val_accuracy: 0.6976
# Epoch 10/10
# 782/782 [==============================] - 46s 59ms/step - loss: 0.6677 - accuracy: 0.7650 - val_loss: 0.8678 - val_accuracy: 0.7060
# Predicted class label: 2
